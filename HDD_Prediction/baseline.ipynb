# %% [markdown]
# # Training

# %%
import os
import pandas as pd

def find_failure_rows_in_files(folder_path):
    # 初始化空的列表来保存正负样本
    failure_1_samples = []
    failure_0_samples = []

    # 遍历文件夹中的所有 CSV 文件
    for filename in os.listdir(folder_path):
        if filename.endswith('.csv'):
            file_path = os.path.join(folder_path, filename)
            print(f"Processing file: {file_path}")

            # 读取 CSV 文件
            df = pd.read_csv(file_path)

            # 确保文件中有 "failure" 列
            if 'failure' not in df.columns:
                print(f"Skipping file {filename}: 'failure' column not found.")
                continue

            # 筛选出 failure=1 和 failure=0 的行
            failure_1_rows = df[df['failure'] == 1]
            failure_0_rows = df[df['failure'] == 0]

            # 添加到正负样本集合中，直到各自有 1491 行
            if len(failure_1_samples) < 1491:
                # 计算需要添加的正样本数量
                remaining_1 = 1491 - len(failure_1_samples)
                failure_1_samples.extend(failure_1_rows.head(remaining_1).to_dict(orient='records'))

            if len(failure_0_samples) < 1491:
                # 计算需要添加的负样本数量
                remaining_0 = 1491 - len(failure_0_samples)
                failure_0_samples.extend(failure_0_rows.head(remaining_0).to_dict(orient='records'))

            # 如果两个集合都已满足条件，停止遍历文件
            if len(failure_1_samples) >= 1491 and len(failure_0_samples) >= 1491:
                print(f"Found 1491 positive and 1491 negative samples in {filename}. Stopping.")
                break  # 停止遍历文件夹

    # 将正负样本合并成一个 DataFrame 返回
    final_samples = failure_1_samples[:1491] + failure_0_samples[:1491]
    final_df = pd.DataFrame(final_samples)
    return final_df

# 使用该函数
folder_path = "/mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset"  # 修改为你的文件夹路径
result_df = find_failure_rows_in_files(folder_path)

# 显示最终结果
print(f"Final DataFrame shape: {result_df.shape}")
# Out:
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-01.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-02.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-03.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-04.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-05.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-06.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-07.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-08.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-09.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-10.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-11.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-12.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-13.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-14.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-15.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-16.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-17.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-18.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-19.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-20.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-21.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-22.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-23.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-24.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-25.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-26.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-27.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-28.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-29.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-30.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-01-31.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-01.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-02.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-03.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-04.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-05.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-06.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-07.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-08.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-09.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-10.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-11.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-12.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-13.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-14.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-15.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-16.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-17.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-18.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-19.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-20.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-21.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-22.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-23.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-24.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-25.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-26.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-27.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-28.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-02-29.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-01.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-02.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-03.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-04.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-05.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-06.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-07.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-08.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-09.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-10.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-11.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-12.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-13.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-14.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-15.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-16.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-17.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-18.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-19.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-20.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-21.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-22.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-23.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-24.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-25.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-26.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-27.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-28.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-29.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-30.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-03-31.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-01.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-02.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-03.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-04.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-05.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-06.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-07.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-08.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-09.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-10.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-11.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-12.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-13.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-14.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-15.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-16.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-17.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-18.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-19.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-20.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-21.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-22.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-23.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-24.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-25.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-26.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-27.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-28.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-29.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-04-30.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-01.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-02.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-03.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-04.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-05.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-06.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-07.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-08.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-09.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-10.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-11.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-12.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-13.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-14.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-15.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-16.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-17.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-18.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-19.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-20.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-21.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-22.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-23.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-24.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-25.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-26.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-27.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-28.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-29.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-30.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-05-31.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-01.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-02.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-03.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-04.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-05.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-06.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-07.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-08.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-09.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-10.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-11.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-12.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-13.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-14.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-15.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-16.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-17.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-18.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-19.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-20.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-21.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-22.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-23.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-24.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-25.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-26.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-27.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-28.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-29.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-06-30.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-01.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-02.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-03.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-04.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-05.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-06.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-07.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-08.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-09.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-10.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-11.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-12.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-13.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-14.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-15.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-16.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-17.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-18.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-19.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-20.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-21.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-22.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-23.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-24.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-25.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-26.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-27.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-28.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-29.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-30.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-07-31.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-01.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-02.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-03.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-04.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-05.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-06.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-07.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-08.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-09.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-10.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-11.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-12.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-13.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-14.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-15.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-16.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-17.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-18.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-19.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-20.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-21.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-22.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-23.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-24.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-25.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-26.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-27.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-28.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-29.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-30.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-08-31.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-01.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-02.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-03.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-04.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-05.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-06.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-07.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-08.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-09.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-10.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-11.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-12.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-13.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-14.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-15.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-16.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-17.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-18.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-19.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-20.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-21.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-22.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-23.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-24.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-25.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-26.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-27.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-28.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-29.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-09-30.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-01.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-02.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-03.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-04.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-05.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-06.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-07.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-08.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-09.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-10.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-11.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-12.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-13.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-14.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-15.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-16.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-17.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-18.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-19.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-20.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-21.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-22.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-23.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-24.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-25.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-26.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-27.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-28.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-29.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-30.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-10-31.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-01.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-02.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-03.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-04.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-05.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-06.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-07.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-08.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-09.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-10.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-11.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-12.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-13.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-14.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-15.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-16.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-17.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-18.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-19.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-20.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-21.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-22.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-23.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-24.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-25.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-26.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-27.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-28.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-29.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-11-30.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-01.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-02.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-03.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-04.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-05.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-06.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-07.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-08.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-09.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-10.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-11.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-12.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-13.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-14.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-15.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-16.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-17.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-18.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-19.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-20.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-21.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-22.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-23.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-24.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-25.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-26.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-27.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-28.csv
# Processing file: /mnt/raid5/sum/card/storage/AI4Storage/HDD_Prediction/dataset/2020-12-29.csv
# Found 1491 positive and 1491 negative samples in 2020-12-29.csv. Stopping.
# Final DataFrame shape: (2982, 149)

# %%
valid = result_df[result_df['failure'] == 0]
failed = result_df[result_df['failure'] == 1]
print("valid hdds:", len(valid))
print("failed hdds:", len(failed))
# Out:
# valid hdds: 1491
# failed hdds: 1491

# %%
valid.iloc[-1]
# Out:
# date                        2020-01-01
# serial_number                 ZJV2ERHT
# model                    ST12000NM0007
# capacity_bytes          12000138625024
# failure                              0
#                              ...
# smart_245_raw                      NaN
# smart_247_normalized               NaN
# smart_247_raw                      NaN
# smart_248_normalized               NaN
# smart_248_raw                      NaN
# Name: 2981, Length: 149, dtype: object

# %%
result_df.to_csv('filtered_samples.csv', index=False)

# %%
result_df.model.value_counts()
# Out:
# model
# ST12000NM0007                         782
# ST4000DM000                           513
# ST8000NM0055                          317
# ST12000NM0008                         229
# ST8000DM002                           221
# HGST HMS5C4040BLE640                  179
# HGST HUH721212ALN604                  176
# TOSHIBA MG07ACA14TA                   159
# TOSHIBA MQ01ABF050                    103
# HGST HMS5C4040ALE640                   43
# TOSHIBA MQ01ABF050M                    38
# ST500LM012 HN                          37
# ST10000NM0086                          35
# HGST HUH721212ALE600                   30
# ST12000NM001G                          29
# WDC WD5000LPVX                         17
# ST500LM030                             14
# ST14000NM001G                          13
# ST6000DX000                            10
# HGST HUH721212ALE604                    9
# HGST HUH728080ALE600                    8
# ST18000NM000J                           2
# ST8000DM004                             2
# TOSHIBA MD04ABA400V                     2
# Seagate BarraCuda SSD ZA250CM10002      2
# ST4000DM005                             2
# Seagate SSD                             2
# DELLBOSS VD                             2
# TOSHIBA HDWF180                         1
# WDC WD5000LPCX                          1
# WDC WUH721414ALE6L4                     1
# ST16000NM001G                           1
# HGST HDS5C4040ALE630                    1
# ST8000DM005                             1
# Name: count, dtype: int64

# %%
df_data_model = result_df[result_df['model'] == 'ST12000NM0007']

# %%
features_specified = []
features = [5, 9, 187, 188, 193, 194, 197, 198, 241, 242]
for feature in features:
    features_specified += ["smart_{0}_raw".format(feature)]

# %%
X_data = df_data_model[features_specified]
Y_data = df_data_model['failure']

# %%
X_data.isnull().sum()
# Out:
# smart_5_raw      1
# smart_9_raw      1
# smart_187_raw    1
# smart_188_raw    1
# smart_193_raw    1
# smart_194_raw    1
# smart_197_raw    1
# smart_198_raw    1
# smart_241_raw    1
# smart_242_raw    1
# dtype: int64

# %%
X_data = X_data.fillna(0)

# %%
import numpy as np
print("valid hdds:", len(Y_data) - np.sum(Y_data.values))
print("failed hdds:", np.sum(Y_data.values))
# Out:
# valid hdds: 438
# failed hdds: 344

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X_data, Y_data, test_size=0.2, random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier 

rfc = RandomForestClassifier()

# %%
rfc.fit(X_train, Y_train)
# Out:
# RandomForestClassifier()

# %%
Y_pred = rfc.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print("Model used is: Random Forest classifier") 
  
acc = accuracy_score(Y_test, Y_pred) 
print("The accuracy is {}".format(acc)) 
  
prec = precision_score(Y_test, Y_pred) 
print("The precision is {}".format(prec)) 
  
rec = recall_score(Y_test, Y_pred) 
print("The recall is {}".format(rec)) 
  
f1 = f1_score(Y_test, Y_pred) 
print("The F1-Score is {}".format(f1))
# Out:
# Model used is: Random Forest classifier
# The accuracy is 0.9554140127388535
# The precision is 0.984375
# The recall is 0.9130434782608695
# The F1-Score is 0.9473684210526315

# %% [markdown]
# # Prediction
